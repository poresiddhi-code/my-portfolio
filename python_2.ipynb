# %% [markdown]
# <a href="https://colab.research.google.com/github/poresiddhi-code/my-portfolio/blob/main/python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operation
# Arithmetic Operation
# Let's first two numbers in a variable print them and their type
num1 = 3
num2 = 5
print(num1,num2)
print(type(num1),type(num2))
# Out:
# 3 5
# <class 'int'> <class 'int'>

# %% [markdown]
# Example

# %%
num1 = 4 # 4 is int
num2 = 5 #5 is int
print(num1,num2)
print(type(num1),type(num2))
# Out:
# 4 5
# <class 'int'> <class 'int'>

# %%
# you can carry out basic + - * / #giving to me the aswer of example
print(num1 + num2) #'+' it is use for adding
print(num1 - num2) #'-' it is use for substracting
print(num1 * num2) # '*' it is use for multiplication
print(num1 / num2) # '/' it is use for dividing
# Out:
# 9
# -1
# 20
# 0.8

# %% [markdown]
# # Example of Arithmatic Operation

# %%
num1 = 2
num2 = 5
print(num1,num2)
print(type(num1),type(num2))
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# 2 5
# <class 'int'> <class 'int'>
# 7
# -3
# 10
# 0.4

# %%
# Other  arithmatic operators - // % **
num1 = 3
num2 = 5
print (num2// num1) ## this is called floor division i.e. the output is quotient without reminder i.e. discarding the numbers after decimal point
print(num2 % num1) ## this is called modulus i.e. the reminder after division
print(3**2) ### exponent (^) ---> 3^2
# Out:
# 1
# 2
# 9

# %% [markdown]
# Example of operation (- // % **)

# %%
num1 = 4
num2 = 7
print(num2//num1)
print(num2 % num1)
print(4**7)
# Out:
# 1
# 3
# 16384

# %% [markdown]
# # some more examples of floor division

# %%
print(9//3)
print(8//3)
print(7//3)
print(6//3)
# Out:
# 3
# 2
# 2
# 2

# %% [markdown]
#  Example of modulus

# %%
print(9 % 3)
print(8 % 3)
print(7 % 3)
print(6 % 3)
# Out:
# 0
# 2
# 1
# 0

# %% [markdown]
# Example of multiple operation

# %%
## Python supports BODMAS rule when multiple operators are in line
print(5* 4 + 1) # first multilpication will be executed
print(1+ 5 * 4) # same as above first multilpication will be executed
print(5*(4+1)) # first brackets then rest
# Out:
# 21
# 21
# 25

# %% [markdown]
# Comparison Operators

# %% [markdown]
# Comparison Operators
# Arithmatic operators carry out arithmatic operations on given numbers (such as + - ...)
#
# Comparison operators on the other hand gives output as either True or False depending upon the comparison.
#
# Examples: == < > <= >= !=
#
#
# [ ]

# %% [markdown]
# # == checks whether left hand side and right hand side is equal

# %%
print( 2==2) # if lhs = Rhs, output True else False
print(2==1)# Here LHS is not equal to RHS
# Out:
# True
# False

# %%
# Example
print (3==3)
print(4==4)
# Out:
# True
# True

# %% [markdown]
# Comparison Operators only do the Comparison (they don't calculate or carry out any arithmatic operations on thier own)

# %%
# Let's explore < > <= >=
print(3 != 2)

print(3 > 2)
print(3 < 2)

print(3>=3)
print(3>=3)

print(3 <=2)
# Out:
# True
# True
# False
# True
# True
# False

# %% [markdown]
# # Example

# %%
print(3 != 2)

print(4 > 3)
print(4 < 2)

print(3>= 3)
print(4>= 4)

print(4 <=3)
# Out:
# True
# True
# False
# True
# True
# False

# %% [markdown]
# Assignment Operator

# %%
# += is a shortcut for add and assign

num = 4
print(num)

num += 1   # is equivalent to num = num + 1
print(num)
# Out:
# 4
# 5

# %% [markdown]
# Example

# %%
# += is a shortcut for add and assign

num = 3
print(num)

num += 1   # is equivalent to num = num + 1
print(num)
# Out:
# 3
# 4

# %% [markdown]
# # -= is a shortcut for subtract and assign

# %%
# -= is a shortcut for subtract and assign

num = 4
print(num)

num -= 1   # is equivalent to num = num - 1
print(num)
# Out:
# 4
# 3

# %% [markdown]
# Example

# %%
num = 3
print(num)

num-=1 # is equivalent to num = num - 1
print(num)
# Out:
# 3
# 2

# %% [markdown]
# for multiplication and equal to

# %%
num = 4
num *= 2
print(num)
# Out:
# 8

# %% [markdown]
# Example

# %%
num = 2
num*= 3
print(num)
# Out:
# 6

# %% [markdown]
# divide

# %%
num = 4
num/= 2
print(num)
# Out:
# 2.0

# %%
num = 4
num /= 2
print(num)
# Out:
# 2.0

# %%
num = 2
num /= 2
print(num)
# Out:
# 1.0

# %% [markdown]
# Lgical Operation

# %% [markdown]
# Basics - 3 Operators - And, Or, Not

# %% [markdown]
# Examples for Logical Operation

# %%
# AND needs both conditions to be True

x = 5
print(x > 4 and x < 6)
# Out:
# True

# %% [markdown]
# Example for and

# %%
x = 4
print(x > 3 and x < 8)
# Out:
# True

# %% [markdown]
#  Or operation

# %%
# OR evaluates for atleast one true condition

x = 5
print(x > 3 or x < 4)  # if any one condition is true, answer is true
# Out:
# True

# %% [markdown]
# Example 2 for or

# %%
x = 6
print(x > 4 or x < 9)
# Out:
# True

# %% [markdown]
# Example of and

# %%
# NOt operater checks for opposite result

x = 5
print(not(x > 3 and x < 10))
# Out:
# False

# %% [markdown]
# Basic Typecasting

# %% [markdown]
# Changing type of variable from one type to another (i.e. str to int or int to str, or str to float or float to str, or bool to str or str to bool)

# %% [markdown]
# Some functions related to int and float

# %%
# Type casting  i.e. converting string to int

a = '2'
b = '3'
print(a, type(a))
print(b, type(b))
print('Addition = ', a+b)   # because this is string + string, the output will be simple concatenation of the digits i.e. output will be 23 instead of 5

print()                     # Leaves a blank space in output

a = int(a)
b = int(b)
print(a, type(a))       # here you'll get output as int
print(b, type(b))       # here you'll get output as int
print('Addition = ', a+b)
# Out:
# 2 <class 'str'>
# 3 <class 'str'>
# Addition =  23
#
# 2 <class 'int'>
# 3 <class 'int'>
# Addition =  5

# %%
a = '3'
b = '5'
print(a, type(a))
print(b, type(b))
print('Addition = ', a+b)   # because this is string + string, the output will be simple concatenation of the digits i.e. output will be 23 instead of 5

print()                     # Leaves a blank space in output

a = int(a)
b = int(b)
print(a, type(a))       # here you'll get output as int
print(b, type(b))       # here you'll get output as int
print('Addition = ', a+b)
# Out:
# 3 <class 'str'>
# 5 <class 'str'>
# Addition =  35
#
# 3 <class 'int'>
# 5 <class 'int'>
# Addition =  8

# %%
# But if you go about typecasting a proper string into int it'll give error
# THIS CELL WILL GIVE ERROR. IT IS MEANT FOR THAT. DON'T WORRY BECAUSE IT IS RED

a = 'hi'
a = int(a)    # this line will throw error (because python cannot convert 'hi' into  integer)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_665/4205277549.py in <cell line: 0>()
#       3
#       4 a = 'hi'
# ----> 5 a = int(a)    # this line will throw error (because python cannot convert 'hi' into  integer)
#       6 print(a)
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %% [markdown]
# FLOAT TO STR

# %%
# Float to str

num = 2.0
print(type(num))
num = str(num)
print(type(num))
# Out:
# <class 'float'>
# <class 'str'>

# %%
num = 3.0
print(type(num))
num = (str(num))
print(type(num))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# String function

# %%
# str to bool

num = 'True'
print(type(num))
num = bool(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
num = 'False'
print(type(num))
num = bool(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Typecasting with input()

# %% [markdown]
# If Else based on comparison operators

# %% [markdown]
# if is a special keyword in python used to denote condition.
#
# Condition requires any of the logical operators we saw above.

# %% [markdown]
# Extra if-else programs for practice

# %%
# multiple if else => use elif

height = 176
if height < 140:
    print('too short')
elif height < 180:
    print('height is ok')
else:
    print('too tall')
# Out:
# height is ok

# %%
weight = 60
if weight < 50:
  print('too loss a weight')
elif weight < 80:
  print('weight is ok')
else:
  print('too heavy')
# Out:
# weight is ok

# %% [markdown]
# Example

# %%
weight = 40
if weight < 50:
  print('too loss a weight')
elif weight < 80:
  print('weight is ok')
else:
  print('too heavy')
# Out:
# to loss a weight

# %%
weight = 90
if weight < 50:
  print('to loss a weight')
elif weight < 80:
  print('weight is ok')
else:
  print('too heavy')
# Out:
# too heavy

# %% [markdown]
# # You can pass boolean value (True or False) to the condition in if. In that case, you don't need any logical operator like == or !=

# %%
# You can pass boolean value (True or False) to the condition in if. In that case, you don't need any logical operator like == or !=


is_subscribed = False
if is_subscribed:              # Read it like - if True do THIS else do THAT
    print('Thank you for the subscription!')
else:
    print('Please subscribe')
# Out:
# Please subscribe

# %% [markdown]
# Example

# %%
is_ = True
if is_ :
  print('thank you for visiting')
else:
  print('please visiting to our website')
# Out:
# thank you for visiting

# %%
is_subscribed = True
if is_subscribed:
    print('Thank you for the subscription!')
else:
    print('Please subscribe')
# Out:
# Thank you for the subscription!

# %% [markdown]
# Example

# %%
is_ =  False
if is_ :
  print('thank you for visiting')
else:
  print('please visiting to our website')
# Out:
# please visiting to our website

# %%
x = 3
y = 4

if x < y and x + y > 5:
    print('both statements are true')

if x < y or x > y:
    print('one of the statement is true')

if x < y and not x + y < 5:
    print('both the statements must be true')
# Out:
# both statements are true
# one of the statement is true
# both the statements must be true

# %%
x = 5
y = 6

if x < y and x + y > 5:
    print('both statements are true')

if x < y or x > y:
    print('one of the statement is true')

if x < y and not x + y < 5:
    print('both the statements must be true')
# Out:
# both statements are true
# one of the statement is true
# both the statements must be true

# %% [markdown]
# # Nested If

# %%
# Nested If

x = 7
if x > 10:
    print('x is greater than 10')
    if x > 20:
        print('x is greater than 20')
        if x > 30:
            print('x is greater than 30')
        else:
            print('x is smaller than 30')
    else:
        print('x is smaller than 20')
else:
    print('x is smaller than 10')
# Out:
# x is smaller than 10

# %% [markdown]
# Example

# %%
x = 7
if x > 15:
    print('x is greater than 15')
    if x > 20:
        print('x is greater than 20')
        if x > 30:
            print('x is greater than 30')
        else:
            print('x is smaller than 30')
    else:
        print('x is smaller than 20')
else:
    print('x is smaller than 10')
# Out:
# x is smaller than 10

# %% [markdown]
# # To find out if inputted number is within the range of 3 to 10
# # if both conditions are True only then answer will be True else false

# %%
# To find out if inputted number is within the range of 3 to 10
# if both conditions are True only then answer will be True else false

x = int(input("Enter any number within range 10: "))     # if you pass anything other than integer, it'll throw error. Because we are typecasting here itself
print(x >= 3 and x <= 10)
# Out:
# Enter any number within range 10: 4
# True

# %% [markdown]
# Example

# %%
x = int(input("Enter any number within range 10: "))     # if you pass anything other than integer, it'll throw error. Because we are typecasting here itself
print(x >= 5 and x <= 10)
# Out:
# Enter any number within range 10: 6
# True

# %%
x = int(input("Enter any number within range 10: "))     # if you pass anything other than integer, it'll throw error. Because we are typecasting here itself
print(x >= 3 and x <= 10)
# Out:
# Enter any number within range 10: 11
# False
